# %%
'''................................................................................................
Write a python program to replicate a Banking system. The following features are mandatory:
1. Account login
2. Amount Depositing
3. Amount Withdrawal
Other than the above features you can add any other also.
....................................................................................................'''
class BankAccount:
    def __init__(self, username, password):
        self.username = username
        self.password = password
        self.balance = 0

    def login(self, entered_username, entered_password):
        if entered_username == self.username and entered_password == self.password:
            print("Login successful!")
            return True
        else:
            print("Invalid username or password!")
            return False

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposit successful. Your deposited amount is:{self.balance}.")
        else:
            print("Invalid amount for deposit.")

    def withdraw(self, amount):
        if amount > 0 and amount <= self.balance:
            self.balance -= amount
            print(f"Withdrawal successful. Your new balance is {self.balance}.")
        else:
            print("Insufficient funds or invalid amount for withdrawal.")

def option():
 print("Select Your Option")
 print("..................")
 print("1.Deposit")
 print("2.Withdraw")
 print("3.Exit")

 d=int(input("Enter Your Option"))

try:
    name=input("Enter Name:")
    password=input("Enter password:")

    b=BankAccount(name,password)

    print("\nLogin\n*****")

    name=input("Enter Name:")
    password=input("Enter password:")

    f=b.login(name,password)
    i=True
    if f==True:
         while i==True:
             print("\nSelect Your Option")
             print("..................\n")
             print("1.Deposit")
             print("2.Withdraw")
             print("3.Exit")
             d=int(input("\nEnter Your Option :"))

             if d==1:

            #Deposit
                amount = float(input("\nEnter amount to deposit: "))
                b.deposit(amount)
             elif d==2:
            #Withdrawal 
                amount = float(input("\nEnter amount to withdraw: "))
                b.withdraw(amount)
             elif d==3:
                print("\nYou Choosen Exit,Byee......!")
                break
             else :
                print("\nInvalid Option")
except Exception as e:
    print("An error occured",e)
# Out:
# Enter Name:se
# Enter password:se
#
# Login
# *****
# Enter Name:se
# Enter password:se
# Login successful!
#
# Select Your Option
# ..................
#
# 1.Deposit
# 2.Withdraw
# 3.Exit
#
# Enter Your Option :1
#
# Enter amount to deposit: 1000
# Deposit successful. Your deposited amount is:1000.0.
#
# Select Your Option
# ..................
#
# 1.Deposit
# 2.Withdraw
# 3.Exit
#
# Enter Your Option :500
#
# Invalid Option
#
# Select Your Option
# ..................
#
# 1.Deposit
# 2.Withdraw
# 3.Exit
#
# Enter Your Option :2
#
# Enter amount to withdraw: 1000
# Withdrawal successful. Your new balance is 0.0.
#
# Select Your Option
# ..................
#
# 1.Deposit
# 2.Withdraw
# 3.Exit
#
# Enter Your Option :3
#
# You Choosen Exit,Byee......!
