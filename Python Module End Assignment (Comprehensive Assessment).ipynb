# %% [markdown]
# Python Module End Assignment (Comprehensive Assessment)
# .......................................................
#
# Dear Students,
#
# Congratulations on completing the Python module!
#
# As a culminating project, you'll be working with a dataset from ABC company, consisting of 458 rows and 9 columns. The company requires a comprehensive report detailing information about their employees across various teams. Your tasks include preprocessing the dataset, analyzing the data, and presenting your findings graphically. Here's a breakdown of what you need to do:
#
# Preprocessing:
# Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis. (1 mark)
#
# Analysis Tasks:
# 1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees. (2 marks)
# 2. Segregate employees based on their positions within the company. (2 marks)
# 3. Identify the predominant age group among employees. (2 marks)
# 4. Discover which team and position have the highest salary expenditure. (2 marks)
# 5. Investigate if there's any correlation between age and salary, and represent it visually. (2 marks)
#
# Graphical Representation:
# For each of the five analysis tasks, create appropriate visualizations to present your findings effectively. (5x2 = 10 marks)
#
# Data Story:
# Provide insights gained from the analysis, highlighting key trends, patterns, and correlations within the dataset. (3 marks)
#
# Timely Submission:
# Ensure timely submission of your project to earn an additional mark. (1 mark)
#
# Total Marks : 25
#
# By completing these tasks, you'll not only demonstrate your proficiency in Python programming but also your ability to analyze and communicate insights from real-world data.
#
# Download the dataset from this link.
#  https://docs.google.com/spreadsheets/d/1VP9BE_eI2yl6uUHSm4mGiiwjRdoqCqnkcIjsv5Q2ex4/edit?usp=share_link
#
# To submit the project:
# 1. Create a repository on your GitHub account.
# 2. Write a comprehensive overview of the project in the README file, summarizing the preprocessing steps, analysis tasks, graphical representations, insights gained, and any additional information.
# 3. Upload a well-organized Jupyter Notebook file containing the code for the project, ensuring proper formatting and documentation.
# 4. Include the dataset in the repository.
# 5. Submit the link to your repository in the designated section on Google Classroom.
#
# Best of luck, and feel free to reach out if you have any questions or need assistance along the way!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#To Access Our dataset

employee=pd.read_csv("C:\\Users\\rajan\\Downloads\\myexcel - myexcel.csv.csv")

display(employee)
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#Info of our data set
display(employee.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB
# None

# %% [markdown]
# insight
# .......
# Total 458 entries
#
# Among that
#   1. Name,Team,Number,Position,Age,Height,Weight have 0 null values
#   2. College,Salary have null values

# %%
#statistical values
employee.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
'''................................................................................................
Preprocessing:
Correct the data in the "height" column by replacing it with random numbers between 150 and 180. 
Ensure data consistency and integrity before proceeding with analysis. (1 mark)
...................................................................................................'''

#Showing current values in column in height

employee=pd.read_csv("C:\\Users\\rajan\\Downloads\\myexcel - myexcel.csv.csv")


print("Showing current values in column in height\n",employee[['Name','Height']].head(30))

print("\nChecking data consistency and integrity by checking summary statistics before correcting data\n\n",employee['Height'].describe())


# Generate random numbers between 150 and 180 for the "height" column

random_heights = np.random.randint(150, 181,size=len(employee))

# Update the "height" column in the DataFrame with the random numbers

employee['Height'] = random_heights

#Current values in column height

print("\nCurrent data in  column height,replaced with random numbers\n\n",employee[['Name','Height']].head(30))

# Ensure data consistency and integrity by checking summary statistics
print("\nChecking data consistency and integrity by checking summary statistics\n\n",employee['Height'].describe())

# Save the updated DataFrame to a new CSV file or proceed with further analysis
employee.to_csv("updated_dataset.csv", index=False)
#employee
# Out:
# Showing current values in column in height
#                         Name  Height
# 0             Avery Bradley  06-Feb
# 1               Jae Crowder  06-Jun
# 2              John Holland  06-May
# 3               R.J. Hunter  06-May
# 4             Jonas Jerebko  06-Oct
# 5              Amir Johnson  06-Sep
# 6             Jordan Mickey  06-Aug
# 7              Kelly Olynyk     7-0
# 8              Terry Rozier  06-Feb
# 9              Marcus Smart  06-Apr
# 10          Jared Sullinger  06-Sep
# 11            Isaiah Thomas  05-Sep
# 12              Evan Turner  06-Jul
# 13              James Young  06-Jun
# 14             Tyler Zeller     7-0
# 15         Bojan Bogdanovic  06-Aug
# 16             Markel Brown  06-Mar
# 17          Wayne Ellington  06-Apr
# 18  Rondae Hollis-Jefferson  06-Jul
# 19             Jarrett Jack  06-Mar
# 20           Sergey Karasev  06-Jul
# 21          Sean Kilpatrick  06-Apr
# 22             Shane Larkin  05-Nov
# 23              Brook Lopez     7-0
# ...

# %% [markdown]
# Insight
# .......
# While we go through the column height we will understand the column containing the unrelevent datas like date.
# Hence processed the column height ,and replace those values with random height values generated using 'randomint' fn.

# %%
'''....................................................................................................................
Analysis Tasks:
1. Determine the distribution of employees across each team and calculate the percentage split relative to the 
total number of employees. (2 marks)
.......................................................................................................................'''

import pandas as pd
import matplotlib.pyplot as plt


# Count the number of employees in each team

team_counts = employee['Team'].value_counts()
print(team_counts)
# Calculate the percentage split relative to the total number of employees

percentage_split = (team_counts / len(employee)) * 100


# Display the percentage split relative to the total number of employees
print("\nPercentage of Spliting Across Teams:\n\n")
print(percentage_split)
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64
#
# ...

# %%
# Plotting the distribution of employees across each team

plt.figure(figsize=(10, 6))
team_counts.plot(kind='bar', color='indigo')
plt.title('Distribution of Employees Across Teams')
plt.xlabel('Team')
plt.ylabel('Number of Employees')
plt.legend()

plt.grid(axis='y', linestyle='--')

plt.show()

# %% [markdown]
# Insights
# ........
# From the barchart we ploted we will understan that
#    1. Most number of employees are from New Orleans Pelicans around 18
#    2. Second most is from team Memphis Grizzlies more than 17
#    3. Next Utah Jazz,New York Knicks,Milwaukee Bucks have more than 15 employees
#    4. And the most of the team have around 15 employees except Orlando Magic,Minnesota Timberwolves,thay have 14 employess.
#       and they have less number of employees among these teams.

# %%
'''..............................................................................
2. Segregate employees based on their positions within the company. (2 marks)
..................................................................................'''

# Segregate employees based on their positions
position_groups = df['Position'].value_counts()

print(position_groups)

#Plotting Pi-Chart for easy understanding 

plt.figure(figsize=(10, 6))
plt.pie(position_groups,labels=position_groups.index,autopct="%1.1f%%")
plt.title('Employees Position')
plt.show()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# Insight
# .......
# By segregating data and plotting the bar chart we will understand that
#   1. Most of the empolees are in the position 'SG' around 22.3%
#   2. Least number of employess are in the position 'C' around 17.2%

# %%
'''...................................................................
3. Identify the predominant age group among employees. (2 marks)
......................................................................'''

# Pre-Dominant ange group of employees
Age_groups = df['Age'].value_counts()

print(Age_groups)

#Plotting Pi-Chart for easy understanding 

plt.figure(figsize=(10, 6))
Age_groups.plot(kind="bar",color="Black")
plt.title('Age Groups Of Employees')
plt.xlabel="Age"
plt.ylabel="Number of Employee"
plt.legend()
plt.grid(axis='y', linestyle='--')

plt.show()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %% [markdown]
# Insight
# .......
# 1. Most of the employees are in the age group of 24 almost 47 employess
# 2. Most of the employees are coming in the age group of 20-32
# 3. Less number of employees are elders and youngsters

# %%
'''....................................................................................
4. Discover which team and position have the highest salary expenditure. (2 marks)
......................................................................................'''


employee['Salary'] = employee['Salary'].astype(float)
highest_Salary = employee['Salary'] .max()


index_max = employee['Salary'] .idxmax()

# Get the name of the player with the maximum Salary

player_name= employee.loc[index_max, 'Name']

print("Highest Salary\nPlayer: ", player_name,'\nSalary:',highest_Salary,)

# Calculate the total salary expenditure for each team-position combination
salary_expenditure = employee.groupby(['Team', 'Position'])['Salary'].sum()

# Find the team and position with the highest salary expenditure
highest_expenditure = salary_expenditure.idxmax()
highest_expenditure_salary = salary_expenditure.max()

# Display the team and position with the highest salary expenditure
print(f"Team with the highest salary expenditure: {highest_expenditure[0]}")
print(f"Position within that team with the highest salary expenditure: {highest_expenditure[1]}")
print(f"Highest salary expenditure: {highest_expenditure_salary}")
# Out:
# Highest Salary
# Player:  Kobe Bryant
# Salary: 25000000.0
# Team with the highest salary expenditure: Los Angeles Lakers
# Position within that team with the highest salary expenditure: SF
# Highest salary expenditure: 31866445.0

# %%
salary_expenditure = df.groupby(['Team', 'Position'])['Salary'].sum().reset_index()

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(salary_expenditure['Position'], salary_expenditure['Salary'], color='violet', alpha=0.7)
plt.title('Salary Expenditure by Team and Position')
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# Insight
# .......
# Team with the highest salary expenditure: Los Angeles Lakers
# Position within that team with the highest salary expenditure: SF
# Highest salary expenditure: 31866445.0
#
# From thde visualization we will undersand that the range of salary is coming under .5 to 2

# %%
#5. Investigate if there's any correlation between age and salary, and represent it visually. (2 marks)

# Calculate the correlation coefficient
correlation_coefficient = df['Age'].corr(df['Salary'])

# Display the correlation coefficient
print(f"Correlation Coefficient between Age and Salary: {correlation_coefficient}")


plt.figure(figsize=(10, 6))
df['Age']=df['Age'].astype(float)
sns.scatterplot(x='Age', y='Salary', data=df, color='skyblue')
plt.title('Age vs. Salary')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Correlation Coefficient between Age and Salary: 0.21400941226570971

# %% [markdown]
# Insight
# .......
# The salary is comparatevely less for less age ang high age.
# Salary amount is moderately high for the age group 22-33
